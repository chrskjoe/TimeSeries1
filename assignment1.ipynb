# %% [markdown]
# # 2.1 & 2.2
# ![image.png](attachment:image.png)
#
# %web_drop_table(WORK.series1);
#
#
# FILENAME REFFILE '/home/u63553527/Time series analysis/111.xlsx';
#
# PROC IMPORT DATAFILE=REFFILE
# 	DBMS=XLSX
# 	OUT=WORK.series1;
# 	GETNAMES=YES;
# RUN;
#
# PROC CONTENTS DATA=WORK.series1; RUN;
#
#
# %web_open_table(WORK.series1);
#
# proc glm data=work.series1;
# class 'Drivmidler i alt'n;
# model 'Drivmidler i alt'n=yime1/solution;
# run;
#
# Estimate the parameters by using least squared estimates, which under unweighted situation is as same as the maximum likelehood estimator.

# %% [markdown]
# # 2.3
